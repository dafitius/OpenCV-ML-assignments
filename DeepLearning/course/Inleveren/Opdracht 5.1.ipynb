# %% [markdown]
# # Opdracht 5.1: ZTDL 4: Deep Learning Intro – shallow model

# %% [markdown]
# a. Bestudeer in ZTDL 4 het Shallow Model dat wordt toegepast op de dataset, zie ook figuur 11.
#
# b. Maak een schets van het neurale netwerk. Geef daarin de weegfactoren weer die moeten worden bepaald tijdens de training
# ![Model%201.PNG](attachment:Model%201.PNG)
#
# c. Waarom werkt het shallow model hier niet?
#
# **Omdat het model meer dan één laag heeft, hierdoor is het model deep en niet shallow.**
