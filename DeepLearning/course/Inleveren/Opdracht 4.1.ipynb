# %% [markdown]
# # Opdracht 4.1

# %%
# Import libraries
# numpy for array and matrices
# matplotlib visualization

import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# sklearn for data sets

from sklearn.datasets import make_circles

# %%
# returns array of coordinates to make a circle
X, y = make_circles(n_samples=1000,
                    noise=0.1,
                    factor=0.2,
                    random_state=0)

# %%
# Print x coordinates
X
# Out:
# array([[ 0.24265541,  0.0383196 ],
#        [ 0.04433036, -0.05667334],
#        [-0.78677748, -0.75718576],
#        ...,
#        [ 0.0161236 , -0.00548034],
#        [ 0.20624715,  0.09769677],
#        [-0.19186631,  0.08916672]])

# %%
# returns amount of indicis with amount of elements at each index
X.shape
# Out:
# (1000, 2)

# %%
#Makes a figure of 5 by 5
plt.figure(figsize=(5, 5))
# Plots a symbol at coordinates. 'ob' means o circle and b mean blue. 'xr' means x cross and r red
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
#limit of axis
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
#Makes a legend for the plotted symbols
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# %%
# groups a liniear stack of layers on a model
model = Sequential()

# %%
# Adds a densely-connected NN layer to the model
model.add(Dense(4, input_shape=(2,), activation='tanh'))

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
# configures the model for learning
model.compile(SGD(learning_rate=0.5), 'binary_crossentropy', metrics=['accuracy'])

# %%
#trains the model
model.fit(X, y, epochs=20)
# Out:
# Epoch 1/40
# 32/32 [==============================] - 0s 517us/step - loss: 0.0321 - accuracy: 0.9990
# Epoch 2/40
# 32/32 [==============================] - 0s 517us/step - loss: 0.0305 - accuracy: 0.9990
# Epoch 3/40
# 32/32 [==============================] - 0s 484us/step - loss: 0.0291 - accuracy: 0.9990
# Epoch 4/40
# 32/32 [==============================] - 0s 517us/step - loss: 0.0277 - accuracy: 0.9990
# Epoch 5/40
# 32/32 [==============================] - 0s 549us/step - loss: 0.0266 - accuracy: 0.9990
# Epoch 6/40
# 32/32 [==============================] - 0s 517us/step - loss: 0.0255 - accuracy: 0.9990
# Epoch 7/40
# 32/32 [==============================] - 0s 517us/step - loss: 0.0244 - accuracy: 0.9990
# Epoch 8/40
# 32/32 [==============================] - 0s 549us/step - loss: 0.0235 - accuracy: 0.9990
# Epoch 9/40
# 32/32 [==============================] - 0s 517us/step - loss: 0.0227 - accuracy: 0.9990
# Epoch 10/40
# ...

# %%
# Makes a equally liniear interval between two points with a nummber of lines
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
# Makes a coordinates matrix with a horizontal and vertical interval
aa, bb = np.meshgrid(hticks, vticks)
# Translates slice objects to concatenation along the second axis.
ab = np.c_[aa.ravel(), bb.ravel()]
# Generates output predictions for the input samples.
c = model.predict(ab)
# Reshapes a tensor
cc = c.reshape(aa.shape)

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')
