# %% [markdown]
# # Opdracht 5.2: ZTDL 4: Deep Learning Intro – deep model

# %% [markdown]
# a. Bestudeer in ZTDL 4 het Deep Model dat wordt toegepast op de dataset, zie ook figuur 11.

# %% [markdown]
# b. Maak een schets van het neurale netwerk. Geef daarin de weegfactoren weer die moeten worden bepaald tijdens de training. Hoeveel lagen heeft dit netwerk?
#
# ![Model%202.PNG](attachment:Model%202.PNG)

# %% [markdown]
# c. Welke optimizer wordt hier toegepast? Leg in eigen woorden uit wat i.h.a. de functie is van een optimizer.
#
# **De optimizer die wordt toegepast is een Adam optimizer. Een optimizer veranderd de attributen van je model zoals weight and learning rate om zo minder data te verliezen.**

# %% [markdown]
# d. Wat is je conclusie op basis van accuracy scores van de trainingset en de testset? M.a.w. hoe goed is classificatie?
#
# **De beste accuracy score die je kan hebben is 1, heft model heeft een resultaat van 0.997 dus dat is heel goed.**

# %% [markdown]
# e. Is hier sprake van overfitting? Licht je antwoord toe
#
# ![Capture.PNG](attachment:Capture.PNG)
#
# **Dit is de accuracy met 100 epochs**

# %% [markdown]
# ![epochs.PNG](attachment:epochs.PNG)
#
# **Dit is de accuracy score met 10 epochs, dat is bijna hetzelfde als 0,997 maar met 10 keer minder iteraties wat veel minder computing speed is. Dus er is sprake van overfitting omdat er veel onnodige iteraties zijn.**
